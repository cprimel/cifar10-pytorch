# %% [markdown]
# # Deep Learning Miniproject
# ## Model training and testing for Google Colab
#
# A live version of this notebook is available [here](https://colab.research.google.com/drive/1vWbWfP1b4aTkLgKY-1Nas5mSjwMp_wBL?usp=sharing).
#
# The following notebook shows how to train and test a model using the scripts provided in the repository. The output saved below is the training and testing of our final results. The training takes approx. 4-5 hrs with a high-memory GPU session.

# %% [markdown]
# ### Step 0: Verify GPU
#
# Before running any scripts, verify GPU. At this time, Colab is typically serving 16GB Tesla T4 instances.

# %%
# !nvidia-smi
# Out:
# Mon Nov 21 14:48:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Step 1: Mount Google Drive
#
# The scripts below use a mounted Google Drive to save checkpoints and logs. Colab has a habit of disconnecting while you are making coffee.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Step 2: Clone repository
#
# Delete stale code if it is there and clone the current repo.

# %%
# !rm -rf /content/cautious-fiesta && git clone https://github.com/cprimel/cautious-fiesta.git
# Out:
# Cloning into 'cautious-fiesta'...
# remote: Enumerating objects: 386, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 386 (delta 19), reused 28 (delta 10), pack-reused 347
# Receiving objects: 100% (386/386), 25.53 MiB | 17.61 MiB/s, done.
# Resolving deltas: 100% (205/205), done.

# %% [markdown]
# ### Step 3: Train model
#
# We can now run the training script. The `log-dir` and `checkpoint-dir` arguments provided may need to be changed depending on whether or not you mounted Google Drive or not.

# %%
# !cd cautious-fiesta && python train.py --config experiments/convmixer256_8_k5_p2_03.yml --log-dir=/content/drive/MyDrive/miniproject/logs --checkpoint-dir=/content/drive/MyDrive/miniproject/ckpts --batch-size=512 --experiment=convmixer256_8_k5_p2_05 --epochs=200
# Out:
# Preparing experiment convmixer256_8_k5_p2_05...
# convmixer256_8_k5_p2 created, # of params: 594,186.
# Files already downloaded and verified
# Epoch 1 complete:
# 	Train Acc: 0.33
# 	Test Acc: 0.52
# 	lr: 0.00203
# 	Time: 88.8s
# Epoch 2 complete:
# 	Train Acc: 0.45
# 	Test Acc: 0.65
# 	lr: 0.00213
# 	Time: 89.7s
# Accuracy increased (0.52 -> 0.65). Saving model...
# Epoch 3 complete:
# 	Train Acc: 0.50
# 	Test Acc: 0.72
# 	lr: 0.00229
# 	Time: 90.9s
# Accuracy increased (0.65 -> 0.72). Saving model...
# Epoch 4 complete:
# 	Train Acc: 0.55
# 	Test Acc: 0.73
# 	lr: 0.00252
# 	Time: 90.2s
# Accuracy increased (0.72 -> 0.73). Saving model...
# Epoch 5 complete:
# 	Train Acc: 0.60
# 	Test Acc: 0.78
# 	lr: 0.00281
# 	Time: 90.0s
# Accuracy increased (0.73 -> 0.78). Saving model...
# Epoch 6 complete:
# 	Train Acc: 0.62
# 	Test Acc: 0.81
# 	lr: 0.00317
# 	Time: 90.1s
# Accuracy increased (0.78 -> 0.81). Saving model...
# Epoch 7 complete:
# 	Train Acc: 0.61
# 	Test Acc: 0.81
# 	lr: 0.00359
# 	Time: 90.4s
# Accuracy increased (0.81 -> 0.81). Saving model...
# Epoch 8 complete:
# 	Train Acc: 0.64
# 	Test Acc: 0.80
# 	lr: 0.00407
# 	Time: 89.9s
# Epoch 9 complete:
# 	Train Acc: 0.64
# 	Test Acc: 0.81
# 	lr: 0.00461
# 	Time: 89.2s
# Accuracy increased (0.81 -> 0.81). Saving model...
# Epoch 10 complete:
# 	Train Acc: 0.65
# 	Test Acc: 0.84
# 	lr: 0.00521
# 	Time: 89.2s
# Accuracy increased (0.81 -> 0.84). Saving model...
# Epoch 11 complete:
# 	Train Acc: 0.65
# 	Test Acc: 0.85
# 	lr: 0.00587
# 	Time: 88.8s
# Accuracy increased (0.84 -> 0.85). Saving model...
# Epoch 12 complete:
# 	Train Acc: 0.69
# 	Test Acc: 0.83
# 	lr: 0.00658
# 	Time: 89.2s
# Epoch 13 complete:
# 	Train Acc: 0.69
# 	Test Acc: 0.85
# 	lr: 0.00734
# 	Time: 88.6s
# Epoch 14 complete:
# 	Train Acc: 0.70
# 	Test Acc: 0.86
# 	lr: 0.00816
# 	Time: 88.5s
# Accuracy increased (0.85 -> 0.86). Saving model...
# Epoch 15 complete:
# 	Train Acc: 0.70
# 	Test Acc: 0.86
# 	lr: 0.00902
# 	Time: 88.7s
# Accuracy increased (0.86 -> 0.86). Saving model...
# Epoch 16 complete:
# 	Train Acc: 0.64
# 	Test Acc: 0.84
# 	lr: 0.00993
# 	Time: 88.3s
# Epoch 17 complete:
# 	Train Acc: 0.71
# 	Test Acc: 0.85
# 	lr: 0.01089
# 	Time: 88.4s
# Epoch 18 complete:
# 	Train Acc: 0.69
# 	Test Acc: 0.85
# 	lr: 0.01189
# 	Time: 88.3s
# Epoch 19 complete:
# 	Train Acc: 0.67
# 	Test Acc: 0.87
# 	lr: 0.01292
# 	Time: 88.4s
# Accuracy increased (0.86 -> 0.87). Saving model...
# Epoch 20 complete:
# 	Train Acc: 0.72
# 	Test Acc: 0.85
# 	lr: 0.01399
# 	Time: 88.3s
# Epoch 21 complete:
# 	Train Acc: 0.70
# 	Test Acc: 0.85
# 	lr: 0.01510
# 	Time: 88.6s
# Epoch 22 complete:
# 	Train Acc: 0.69
# 	Test Acc: 0.86
# 	lr: 0.01623
# 	Time: 88.8s
# Epoch 23 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.88
# 	lr: 0.01739
# 	Time: 88.8s
# Accuracy increased (0.87 -> 0.88). Saving model...
# Epoch 24 complete:
# 	Train Acc: 0.72
# 	Test Acc: 0.86
# 	lr: 0.01858
# 	Time: 88.6s
# Epoch 25 complete:
# 	Train Acc: 0.71
# 	Test Acc: 0.88
# 	lr: 0.01978
# 	Time: 88.5s
# Accuracy increased (0.88 -> 0.88). Saving model...
# Epoch 26 complete:
# 	Train Acc: 0.69
# 	Test Acc: 0.86
# 	lr: 0.02100
# 	Time: 88.5s
# Epoch 27 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.85
# 	lr: 0.02224
# 	Time: 88.2s
# Epoch 28 complete:
# 	Train Acc: 0.72
# 	Test Acc: 0.84
# 	lr: 0.02348
# 	Time: 88.0s
# Epoch 29 complete:
# 	Train Acc: 0.74
# 	Test Acc: 0.87
# 	lr: 0.02474
# 	Time: 88.4s
# Epoch 30 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.85
# 	lr: 0.02599
# 	Time: 88.0s
# Epoch 31 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.87
# 	lr: 0.02725
# 	Time: 88.2s
# Epoch 32 complete:
# 	Train Acc: 0.75
# 	Test Acc: 0.86
# 	lr: 0.02850
# 	Time: 88.2s
# Epoch 33 complete:
# 	Train Acc: 0.72
# 	Test Acc: 0.87
# 	lr: 0.02975
# 	Time: 88.1s
# Epoch 34 complete:
# 	Train Acc: 0.69
# 	Test Acc: 0.86
# 	lr: 0.03098
# 	Time: 88.1s
# Epoch 35 complete:
# 	Train Acc: 0.72
# 	Test Acc: 0.88
# 	lr: 0.03221
# 	Time: 88.5s
# Accuracy increased (0.88 -> 0.88). Saving model...
# Epoch 36 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.85
# 	lr: 0.03341
# 	Time: 88.3s
# Epoch 37 complete:
# 	Train Acc: 0.70
# 	Test Acc: 0.86
# 	lr: 0.03460
# 	Time: 88.2s
# Epoch 38 complete:
# 	Train Acc: 0.72
# 	Test Acc: 0.84
# 	lr: 0.03576
# 	Time: 88.1s
# Epoch 39 complete:
# 	Train Acc: 0.72
# 	Test Acc: 0.83
# 	lr: 0.03689
# 	Time: 88.2s
# Epoch 40 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.88
# 	lr: 0.03800
# 	Time: 88.2s
# Epoch 41 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.88
# 	lr: 0.03907
# 	Time: 88.0s
# Epoch 42 complete:
# 	Train Acc: 0.75
# 	Test Acc: 0.85
# 	lr: 0.04010
# 	Time: 87.6s
# Epoch 43 complete:
# 	Train Acc: 0.70
# 	Test Acc: 0.88
# 	lr: 0.04110
# 	Time: 87.9s
# Epoch 44 complete:
# 	Train Acc: 0.71
# 	Test Acc: 0.88
# 	lr: 0.04206
# 	Time: 87.5s
# Accuracy increased (0.88 -> 0.88). Saving model...
# Epoch 45 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.86
# 	lr: 0.04297
# 	Time: 87.4s
# Epoch 46 complete:
# 	Train Acc: 0.71
# 	Test Acc: 0.88
# 	lr: 0.04383
# 	Time: 87.6s
# Epoch 47 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.88
# 	lr: 0.04465
# 	Time: 87.6s
# Epoch 48 complete:
# 	Train Acc: 0.71
# 	Test Acc: 0.87
# 	lr: 0.04541
# 	Time: 87.7s
# Epoch 49 complete:
# 	Train Acc: 0.74
# 	Test Acc: 0.88
# 	lr: 0.04613
# 	Time: 87.8s
# Epoch 50 complete:
# 	Train Acc: 0.70
# 	Test Acc: 0.89
# 	lr: 0.04678
# 	Time: 87.9s
# Accuracy increased (0.88 -> 0.89). Saving model...
# Epoch 51 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.88
# 	lr: 0.04738
# 	Time: 87.8s
# Epoch 52 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.88
# 	lr: 0.04792
# 	Time: 87.5s
# Epoch 53 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.88
# 	lr: 0.04841
# 	Time: 87.5s
# Epoch 54 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.87
# 	lr: 0.04882
# 	Time: 87.6s
# Epoch 55 complete:
# 	Train Acc: 0.74
# 	Test Acc: 0.81
# 	lr: 0.04918
# 	Time: 87.5s
# Epoch 56 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.85
# 	lr: 0.04948
# 	Time: 87.4s
# Epoch 57 complete:
# 	Train Acc: 0.71
# 	Test Acc: 0.86
# 	lr: 0.04970
# 	Time: 87.5s
# Epoch 58 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.85
# 	lr: 0.04987
# 	Time: 87.3s
# Epoch 59 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.86
# 	lr: 0.04997
# 	Time: 86.9s
# Epoch 60 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.87
# 	lr: 0.05000
# 	Time: 87.6s
# Epoch 61 complete:
# 	Train Acc: 0.75
# 	Test Acc: 0.88
# 	lr: 0.04999
# 	Time: 87.4s
# Epoch 62 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.87
# 	lr: 0.04997
# 	Time: 87.4s
# Epoch 63 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.88
# 	lr: 0.04994
# 	Time: 88.8s
# Epoch 64 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.89
# 	lr: 0.04990
# 	Time: 89.0s
# Epoch 65 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.88
# 	lr: 0.04984
# 	Time: 88.5s
# Epoch 66 complete:
# 	Train Acc: 0.75
# 	Test Acc: 0.86
# 	lr: 0.04977
# 	Time: 88.4s
# Epoch 67 complete:
# 	Train Acc: 0.75
# 	Test Acc: 0.87
# 	lr: 0.04969
# 	Time: 88.8s
# Epoch 68 complete:
# 	Train Acc: 0.71
# 	Test Acc: 0.88
# 	lr: 0.04960
# 	Time: 89.0s
# Epoch 69 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.90
# 	lr: 0.04949
# 	Time: 88.8s
# Accuracy increased (0.89 -> 0.90). Saving model...
# Epoch 70 complete:
# 	Train Acc: 0.75
# 	Test Acc: 0.89
# 	lr: 0.04937
# 	Time: 88.6s
# Epoch 71 complete:
# 	Train Acc: 0.74
# 	Test Acc: 0.89
# 	lr: 0.04924
# 	Time: 88.3s
# Epoch 72 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.90
# 	lr: 0.04910
# 	Time: 88.0s
# Epoch 73 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.89
# 	lr: 0.04894
# 	Time: 88.2s
# Epoch 74 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.90
# 	lr: 0.04878
# 	Time: 88.0s
# Epoch 75 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.91
# 	lr: 0.04860
# 	Time: 88.8s
# Accuracy increased (0.90 -> 0.91). Saving model...
# Epoch 76 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.90
# 	lr: 0.04841
# 	Time: 89.2s
# Epoch 77 complete:
# 	Train Acc: 0.72
# 	Test Acc: 0.87
# 	lr: 0.04820
# 	Time: 89.2s
# Epoch 78 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.89
# 	lr: 0.04799
# 	Time: 89.7s
# Epoch 79 complete:
# 	Train Acc: 0.79
# 	Test Acc: 0.89
# 	lr: 0.04776
# 	Time: 88.6s
# Epoch 80 complete:
# 	Train Acc: 0.72
# 	Test Acc: 0.91
# 	lr: 0.04752
# 	Time: 89.2s
# Epoch 81 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.89
# 	lr: 0.04728
# 	Time: 88.9s
# Epoch 82 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.90
# 	lr: 0.04701
# 	Time: 89.1s
# Epoch 83 complete:
# 	Train Acc: 0.75
# 	Test Acc: 0.88
# 	lr: 0.04674
# 	Time: 89.2s
# Epoch 84 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.89
# 	lr: 0.04646
# 	Time: 89.5s
# Epoch 85 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.88
# 	lr: 0.04617
# 	Time: 89.8s
# Epoch 86 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.89
# 	lr: 0.04586
# 	Time: 89.5s
# Epoch 87 complete:
# 	Train Acc: 0.73
# 	Test Acc: 0.91
# 	lr: 0.04555
# 	Time: 89.3s
# Accuracy increased (0.91 -> 0.91). Saving model...
# Epoch 88 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.90
# 	lr: 0.04523
# 	Time: 89.1s
# Epoch 89 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.90
# 	lr: 0.04489
# 	Time: 89.4s
# Epoch 90 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.90
# 	lr: 0.04455
# 	Time: 89.3s
# Epoch 91 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.90
# 	lr: 0.04419
# 	Time: 90.0s
# Epoch 92 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.90
# 	lr: 0.04383
# 	Time: 90.4s
# Epoch 93 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.87
# 	lr: 0.04345
# 	Time: 90.7s
# Epoch 94 complete:
# 	Train Acc: 0.74
# 	Test Acc: 0.90
# 	lr: 0.04307
# 	Time: 90.2s
# Epoch 95 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.91
# 	lr: 0.04268
# 	Time: 88.9s
# Epoch 96 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.89
# 	lr: 0.04228
# 	Time: 89.2s
# Epoch 97 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.90
# 	lr: 0.04187
# 	Time: 88.8s
# Epoch 98 complete:
# 	Train Acc: 0.74
# 	Test Acc: 0.91
# 	lr: 0.04145
# 	Time: 88.7s
# Epoch 99 complete:
# 	Train Acc: 0.79
# 	Test Acc: 0.90
# 	lr: 0.04102
# 	Time: 89.0s
# Epoch 100 complete:
# 	Train Acc: 0.79
# 	Test Acc: 0.91
# 	lr: 0.04059
# 	Time: 89.1s
# Epoch 101 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.90
# 	lr: 0.04014
# 	Time: 89.2s
# Epoch 102 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.92
# 	lr: 0.03969
# 	Time: 89.3s
# Accuracy increased (0.91 -> 0.92). Saving model...
# Epoch 103 complete:
# 	Train Acc: 0.79
# 	Test Acc: 0.91
# 	lr: 0.03924
# 	Time: 88.9s
# Epoch 104 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.91
# 	lr: 0.03877
# 	Time: 89.2s
# Epoch 105 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.91
# 	lr: 0.03830
# 	Time: 89.2s
# Epoch 106 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.90
# 	lr: 0.03782
# 	Time: 89.3s
# Epoch 107 complete:
# 	Train Acc: 0.79
# 	Test Acc: 0.89
# 	lr: 0.03734
# 	Time: 89.3s
# Epoch 108 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.88
# 	lr: 0.03685
# 	Time: 89.3s
# Epoch 109 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.91
# 	lr: 0.03635
# 	Time: 88.9s
# Epoch 110 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.91
# 	lr: 0.03585
# 	Time: 89.8s
# Epoch 111 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.92
# 	lr: 0.03534
# 	Time: 89.4s
# Epoch 112 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.92
# 	lr: 0.03483
# 	Time: 88.9s
# Epoch 113 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.88
# 	lr: 0.03431
# 	Time: 88.1s
# Epoch 114 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.91
# 	lr: 0.03378
# 	Time: 87.8s
# Epoch 115 complete:
# 	Train Acc: 0.79
# 	Test Acc: 0.93
# 	lr: 0.03326
# 	Time: 88.0s
# Accuracy increased (0.92 -> 0.93). Saving model...
# Epoch 116 complete:
# 	Train Acc: 0.79
# 	Test Acc: 0.91
# 	lr: 0.03273
# 	Time: 87.8s
# Epoch 117 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.92
# 	lr: 0.03219
# 	Time: 88.6s
# Epoch 118 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.93
# 	lr: 0.03165
# 	Time: 88.4s
# Accuracy increased (0.93 -> 0.93). Saving model...
# Epoch 119 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.92
# 	lr: 0.03111
# 	Time: 88.5s
# Epoch 120 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.92
# 	lr: 0.03056
# 	Time: 88.3s
# Epoch 121 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.93
# 	lr: 0.03001
# 	Time: 88.3s
# Accuracy increased (0.93 -> 0.93). Saving model...
# Epoch 122 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.92
# 	lr: 0.02946
# 	Time: 88.2s
# Epoch 123 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.91
# 	lr: 0.02891
# 	Time: 88.3s
# Epoch 124 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.91
# 	lr: 0.02836
# 	Time: 88.7s
# Epoch 125 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.93
# 	lr: 0.02780
# 	Time: 88.0s
# Accuracy increased (0.93 -> 0.93). Saving model...
# Epoch 126 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.91
# 	lr: 0.02724
# 	Time: 87.8s
# Epoch 127 complete:
# 	Train Acc: 0.84
# 	Test Acc: 0.91
# 	lr: 0.02668
# 	Time: 87.7s
# Epoch 128 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.93
# 	lr: 0.02612
# 	Time: 87.7s
# Epoch 129 complete:
# 	Train Acc: 0.83
# 	Test Acc: 0.93
# 	lr: 0.02556
# 	Time: 87.3s
# Epoch 130 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.93
# 	lr: 0.02500
# 	Time: 87.8s
# Accuracy increased (0.93 -> 0.93). Saving model...
# Epoch 131 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.93
# 	lr: 0.02444
# 	Time: 88.2s
# Epoch 132 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.92
# 	lr: 0.02388
# 	Time: 88.2s
# Epoch 133 complete:
# 	Train Acc: 0.76
# 	Test Acc: 0.92
# 	lr: 0.02332
# 	Time: 87.7s
# Epoch 134 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.93
# 	lr: 0.02276
# 	Time: 87.2s
# Epoch 135 complete:
# 	Train Acc: 0.77
# 	Test Acc: 0.92
# 	lr: 0.02220
# 	Time: 87.5s
# Epoch 136 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.93
# 	lr: 0.02164
# 	Time: 87.7s
# Epoch 137 complete:
# 	Train Acc: 0.78
# 	Test Acc: 0.93
# 	lr: 0.02109
# 	Time: 87.4s
# Epoch 138 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.93
# 	lr: 0.02054
# 	Time: 87.4s
# Epoch 139 complete:
# 	Train Acc: 0.79
# 	Test Acc: 0.94
# 	lr: 0.01999
# 	Time: 87.2s
# Accuracy increased (0.93 -> 0.94). Saving model...
# Epoch 140 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.94
# 	lr: 0.01944
# 	Time: 87.5s
# Accuracy increased (0.94 -> 0.94). Saving model...
# Epoch 141 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.94
# 	lr: 0.01889
# 	Time: 87.3s
# Epoch 142 complete:
# 	Train Acc: 0.83
# 	Test Acc: 0.94
# 	lr: 0.01835
# 	Time: 86.9s
# Epoch 143 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.94
# 	lr: 0.01781
# 	Time: 87.0s
# Epoch 144 complete:
# 	Train Acc: 0.84
# 	Test Acc: 0.94
# 	lr: 0.01727
# 	Time: 87.4s
# Epoch 145 complete:
# 	Train Acc: 0.83
# 	Test Acc: 0.94
# 	lr: 0.01674
# 	Time: 87.1s
# Epoch 146 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.94
# 	lr: 0.01622
# 	Time: 87.5s
# Epoch 147 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.94
# 	lr: 0.01569
# 	Time: 87.1s
# Epoch 148 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.93
# 	lr: 0.01517
# 	Time: 87.3s
# Epoch 149 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.95
# 	lr: 0.01466
# 	Time: 87.0s
# Accuracy increased (0.94 -> 0.95). Saving model...
# Epoch 150 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.94
# 	lr: 0.01415
# 	Time: 86.8s
# Epoch 151 complete:
# 	Train Acc: 0.75
# 	Test Acc: 0.94
# 	lr: 0.01365
# 	Time: 87.3s
# Epoch 152 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.94
# 	lr: 0.01315
# 	Time: 87.5s
# Epoch 153 complete:
# 	Train Acc: 0.84
# 	Test Acc: 0.95
# 	lr: 0.01266
# 	Time: 87.5s
# Accuracy increased (0.95 -> 0.95). Saving model...
# Epoch 154 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.94
# 	lr: 0.01218
# 	Time: 86.9s
# Epoch 155 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.94
# 	lr: 0.01170
# 	Time: 87.2s
# Epoch 156 complete:
# 	Train Acc: 0.87
# 	Test Acc: 0.95
# 	lr: 0.01123
# 	Time: 86.9s
# Epoch 157 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.94
# 	lr: 0.01076
# 	Time: 87.1s
# Epoch 158 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.95
# 	lr: 0.01031
# 	Time: 87.3s
# Epoch 159 complete:
# 	Train Acc: 0.84
# 	Test Acc: 0.95
# 	lr: 0.00986
# 	Time: 86.9s
# Accuracy increased (0.95 -> 0.95). Saving model...
# Epoch 160 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.94
# 	lr: 0.00941
# 	Time: 87.0s
# Epoch 161 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.94
# 	lr: 0.00898
# 	Time: 86.9s
# Epoch 162 complete:
# 	Train Acc: 0.84
# 	Test Acc: 0.94
# 	lr: 0.00855
# 	Time: 87.2s
# Epoch 163 complete:
# 	Train Acc: 0.80
# 	Test Acc: 0.95
# 	lr: 0.00813
# 	Time: 86.9s
# Epoch 164 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.95
# 	lr: 0.00772
# 	Time: 87.7s
# Accuracy increased (0.95 -> 0.95). Saving model...
# Epoch 165 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.95
# 	lr: 0.00732
# 	Time: 87.5s
# Epoch 166 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.95
# 	lr: 0.00693
# 	Time: 87.4s
# Epoch 167 complete:
# 	Train Acc: 0.83
# 	Test Acc: 0.95
# 	lr: 0.00655
# 	Time: 87.1s
# Epoch 168 complete:
# 	Train Acc: 0.83
# 	Test Acc: 0.95
# 	lr: 0.00617
# 	Time: 87.5s
# Accuracy increased (0.95 -> 0.95). Saving model...
# Epoch 169 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.95
# 	lr: 0.00581
# 	Time: 87.4s
# Epoch 170 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.95
# 	lr: 0.00545
# 	Time: 87.2s
# Epoch 171 complete:
# 	Train Acc: 0.86
# 	Test Acc: 0.95
# 	lr: 0.00511
# 	Time: 87.2s
# Epoch 172 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.96
# 	lr: 0.00477
# 	Time: 87.3s
# Accuracy increased (0.95 -> 0.96). Saving model...
# Epoch 173 complete:
# 	Train Acc: 0.88
# 	Test Acc: 0.96
# 	lr: 0.00445
# 	Time: 87.7s
# Epoch 174 complete:
# 	Train Acc: 0.86
# 	Test Acc: 0.96
# 	lr: 0.00414
# 	Time: 88.0s
# Epoch 175 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.96
# 	lr: 0.00383
# 	Time: 88.5s
# Accuracy increased (0.96 -> 0.96). Saving model...
# Epoch 176 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.96
# 	lr: 0.00354
# 	Time: 88.5s
# Accuracy increased (0.96 -> 0.96). Saving model...
# Epoch 177 complete:
# 	Train Acc: 0.84
# 	Test Acc: 0.96
# 	lr: 0.00326
# 	Time: 88.1s
# Epoch 178 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.95
# 	lr: 0.00299
# 	Time: 88.4s
# Epoch 179 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.95
# 	lr: 0.00273
# 	Time: 88.1s
# Epoch 180 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.96
# 	lr: 0.00248
# 	Time: 87.7s
# Epoch 181 complete:
# 	Train Acc: 0.83
# 	Test Acc: 0.95
# 	lr: 0.00224
# 	Time: 87.3s
# Epoch 182 complete:
# 	Train Acc: 0.88
# 	Test Acc: 0.96
# 	lr: 0.00201
# 	Time: 87.5s
# Epoch 183 complete:
# 	Train Acc: 0.89
# 	Test Acc: 0.96
# 	lr: 0.00180
# 	Time: 87.1s
# Accuracy increased (0.96 -> 0.96). Saving model...
# Epoch 184 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.96
# 	lr: 0.00159
# 	Time: 87.3s
# Epoch 185 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.96
# 	lr: 0.00140
# 	Time: 87.2s
# Epoch 186 complete:
# 	Train Acc: 0.84
# 	Test Acc: 0.96
# 	lr: 0.00122
# 	Time: 87.3s
# Epoch 187 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.96
# 	lr: 0.00106
# 	Time: 87.3s
# Epoch 188 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.95
# 	lr: 0.00090
# 	Time: 87.3s
# Epoch 189 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.96
# 	lr: 0.00076
# 	Time: 87.5s
# Epoch 190 complete:
# 	Train Acc: 0.86
# 	Test Acc: 0.96
# 	lr: 0.00063
# 	Time: 87.2s
# Epoch 191 complete:
# 	Train Acc: 0.87
# 	Test Acc: 0.96
# 	lr: 0.00051
# 	Time: 87.4s
# Accuracy increased (0.96 -> 0.96). Saving model...
# Epoch 192 complete:
# 	Train Acc: 0.86
# 	Test Acc: 0.96
# 	lr: 0.00040
# 	Time: 87.1s
# Accuracy increased (0.96 -> 0.96). Saving model...
# Epoch 193 complete:
# 	Train Acc: 0.86
# 	Test Acc: 0.96
# 	lr: 0.00031
# 	Time: 87.5s
# Epoch 194 complete:
# 	Train Acc: 0.82
# 	Test Acc: 0.96
# 	lr: 0.00023
# 	Time: 87.3s
# Epoch 195 complete:
# 	Train Acc: 0.86
# 	Test Acc: 0.96
# 	lr: 0.00016
# 	Time: 87.6s
# Epoch 196 complete:
# 	Train Acc: 0.85
# 	Test Acc: 0.96
# 	lr: 0.00010
# 	Time: 87.3s
# Epoch 197 complete:
# 	Train Acc: 0.87
# 	Test Acc: 0.96
# 	lr: 0.00006
# 	Time: 87.3s
# Epoch 198 complete:
# 	Train Acc: 0.84
# 	Test Acc: 0.96
# 	lr: 0.00003
# 	Time: 87.3s
# Epoch 199 complete:
# 	Train Acc: 0.87
# 	Test Acc: 0.96
# 	lr: 0.00001
# 	Time: 87.0s
# Epoch 200 complete:
# 	Train Acc: 0.81
# 	Test Acc: 0.96
# 	lr: 0.00000
# 	Time: 87.5s

# %% [markdown]
# ### Step 5: Evaluate model on test data
#
# Colab has likely disconnected while you were away. If so, redo Step 0-2. Now, find the latest checkpoint saved in the appropriate directory in the checkpoint folder. This will be the checkpoint with the highest validation accuracy. Copy its path below and provide the relevant commandline arguments that fit your case.

# %%
# !cd cautious-fiesta && python test.py --model=convmixer256_8_k5_p2 --experiment=convmixer256_8_k5_p2_05 --checkpoint=/content/drive/MyDrive/miniproject/ckpts/convmixer256_8_k5_p2_05/convmixer256_8_k5_p2_191_1669012398.121431.pt --logs=/content/drive/MyDrive/miniproject/logs
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to .data/cifar-10-python.tar.gz
# 100% 170498071/170498071 [00:13<00:00, 12533631.85it/s]
# Extracting .data/cifar-10-python.tar.gz to .data
# Test: [10/40     Acc:  0.949     Time: 0.0035
# Test: [20/40     Acc:  0.948     Time: 0.0033
# Test: [30/40     Acc:  0.950     Time: 0.0031
# Test: [40/40     Acc:  0.950     Time: 0.0080
# Results:
# 	Test Acc: 0.950
